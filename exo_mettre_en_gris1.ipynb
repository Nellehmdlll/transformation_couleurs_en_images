# %%
# Remplacez 'mon_nouveau_dossier' par le nom que vous souhaitez donner à votre dossier
# !mkdir mon_nouveau_dossier

# Vous pouvez vérifier que le dossier a été créé en listant son contenu
# !ls -F
# Out:
# detecter_couleurs_bleu_and_red.ipynb  mon_nouveau_dossier/
# drive/				      sample_data/

# %%
# Importez le jeton depuis les secrets de Colab
from google.colab import userdata

# Assurez-vous que le secret est nommé 'GITHUB_TOKEN' dans l'interface des secrets de Colab
GITHUB_TOKEN = userdata.get('GITHUB').strip() # Important: utiliser 'GITHUB_TOKEN' et .strip()
GITHUB_USERNAME = 'Nellehmdlll' # Remplacez par votre nom d'utilisateur GitHub

# Configurez Git avec vos informations
# !git config --global user.email "sdgrahima@gmail.com" # Remplacez par votre email GitHub
# !git config --global user.name "{GITHUB_USERNAME}"

# Naviguez vers le dossier où se trouvent vos fichiers (par exemple, 'mon_nouveau_dossier')
# %cd mon_nouveau_dossier
# !git init

# Vérifiez si 'origin' existe déjà et le supprimez pour éviter 'remote origin already exists'
#!git remote rm origin 2> /dev/null || true

# Ajoutez le remote en utilisant le token pour l'authentification. Ceci est nécessaire pour les dépôts privés.
# !git remote add origin https://{GITHUB_USERNAME}:{GITHUB_TOKEN}@github.com/{GITHUB_USERNAME}/transformation_couleurs_en_images.git

# Après avoir initialisé un nouveau dépôt, vous devrez créer ce dépôt vide sur GitHub manuellement via l'interface web de GitHub.
# Out:
# [Errno 2] No such file or directory: 'mon_nouveau_dossier'
# /content/mon_nouveau_dossier
# Reinitialized existing Git repository in /content/mon_nouveau_dossier/.git/
# error: remote origin already exists.

# %%
# Assurez-vous que le fichier ewo_mettre_en1.ipynb existe dans le répertoire racine de Colab (ou ajustez le chemin)
# Déplacez le fichier existant dans votre dossier Git
# !mv "/content/mon_nouveau_dossier/exo_mettre_en_gris1.ipynb" ./exo_mettre_en_gris1.ipynb
# !mv "/content/drive/MyDrive/Colab Notebooks/conversion_HSV.ipynb" ./conversion_HSV.ipynb
# !mv "/content/drive/MyDrive/Colab Notebooks/sample_data/detecter_couleurs_bleu_and_red.ipynb" ./detecter_couleurs_bleu_and_red.ipynb
# Créez d'autres fichiers d'exemple dans votre dossier si vous le souhaitez


# Ajoutez tous les fichiers modifiés ou nouveaux au 'staging area'
# !git add .

# Comittez les changements
# !git commit -m "Fichier 3"

# Poussez les changements vers la branche principale (ou 'main'/'master') de votre dépôt GitHub
#!git branch -M main
# !git push -f origin main
# Out:
# mv: cannot stat '/content/drive/MyDrive/Colab Notebooks/detecter_couleurs_bleu_and_red.ipynb': No such file or directory
# On branch main
# nothing to commit, working tree clean
# Enumerating objects: 3, done.
# Counting objects: 100% (3/3), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 183.78 KiB | 10.81 MiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/Nellehmdlll/transformation_couleurs_en_images.git
#  + 1dd68df...ca538b3 main -> main (forced update)

# %%
import cv2
import numpy as np

# %%
from google.colab import files

uploaded = files.upload()

for filename in uploaded.keys():
  print(f'Uploaded file: {filename}')
# Out:
#      <input type="file" id="files-b891fc53-0e67-4fed-b729-a00df7451dee" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b891fc53-0e67-4fed-b729-a00df7451dee">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab.patches import cv2_imshow

img = cv2.imread("Go8WJqs4RI6uGH0u1lWIAg@2k.webp")

# convertir en gris
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

cv2_imshow(img)
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x1024>
# <PIL.Image.Image image mode=L size=1024x1024>
